# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create some sample data
data = np.random.randn(100, 4)

# Convert the NumPy array to a pandas DataFrame
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D'])

# Create a histogram
sns.histplot(df['A'], kde=True)
plt.title('Hameedas Histogram Example')
plt.show()

# Create a boxplot
sns.boxplot(data=df)
plt.title('Hameedas Boxplot Example')
plt.show()

# Create a pairplot (includes histograms and scatter plots)
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(12, 6))

for i, feature in enumerate(iris.feature_names):
    plt.subplot(2, 2, i+1)
    sns.histplot(data=df, x=feature, kde=True)
    plt.title(feature)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 plt.figure(figsize=(12, 6))
# ----> 3 for i, feature in enumerate(iris.feature_names):
#       4     plt.subplot(2, 2, i+1)
#       5     sns.histplot(data=df, x=feature, kde=True)
#
# NameError: name 'iris' is not defined

# %%
plt.figure(figsize=(12, 12))

for i, feature in enumerate(iris.feature_names):
    plt.subplot(4, 2, 2*i+1)
    sns.histplot(data=df, x=feature, kde=True)
    plt.title(feature)

    plt.subplot(4, 2, 2*i+2)
    sns.boxplot(data=df, x='species', y=feature)
    plt.title(feature)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 plt.figure(figsize=(12, 12))
# ----> 3 for i, feature in enumerate(iris.feature_names):
#       4     plt.subplot(4, 2, 2*i+1)
#       5     sns.histplot(data=df, x=feature, kde=True)
#
# NameError: name 'iris' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create some sample data
data = np.random.randn(100, 4)

# Convert the NumPy array to a pandas DataFrame
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D'])

# Create a histogram
sns.histplot(df['A'], kde=True)
plt.title('Hameedas Histogram Example')
plt.show()

# Create a boxplot
sns.boxplot(data=df)
plt.title('Hameedas Boxplot Example')
plt.show()

# Create a pairplot (includes histograms and scatter plots)
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
